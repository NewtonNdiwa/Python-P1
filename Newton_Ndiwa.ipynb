# %% [markdown]
# # **PYTHON PROJECT 1**
# Newton Ndiwa

# %% [markdown]
# ### **Importing pandas and numpy libraries**

# %%
import pandas as pd
import numpy as np

# %%
df_1=pd.read_csv('//content//anime_ratings_data - Copy.csv')
df_1
# Out:
#                                                   title    mediaType  eps  \
# 0              Dragon Ball Z Movie 15: Resurrection 'F'        Movie    1
# 1                                     Kuripuri*Kuripura        Movie    1
# 2                                                GJ-bu@   TV Special    1
# 3                    Nausicaa of the Valley of the Wind        Movie    1
# 4                                   Miru Tights Special  DVD Special    1
# ...                                                 ...          ...  ...
# 6518  Watamote: No Matter How I Look at It, It's You...           TV   12
# 6519                                Eight Clouds Rising          OVA    2
# 6520         Ishifuro: Ryuu no Tani to Taiyou no Toride  Music Video    1
# 6521                      Sword Art Online: Alicization           TV   24
# 6522                                       xxxHOLiC Kei           TV   13
#
#       duration  startYr  finishYr  \
# 0         67.0     2015      2015
# ...

# %%
df_2=pd.read_csv(r'/content/anime_ratings_data - Copy.csv')
df_2
# Out:
#                                                   title    mediaType  eps  \
# 0              Dragon Ball Z Movie 15: Resurrection 'F'        Movie    1
# 1                                     Kuripuri*Kuripura        Movie    1
# 2                                                GJ-bu@   TV Special    1
# 3                    Nausicaa of the Valley of the Wind        Movie    1
# 4                                   Miru Tights Special  DVD Special    1
# ...                                                 ...          ...  ...
# 6518  Watamote: No Matter How I Look at It, It's You...           TV   12
# 6519                                Eight Clouds Rising          OVA    2
# 6520         Ishifuro: Ryuu no Tani to Taiyou no Toride  Music Video    1
# 6521                      Sword Art Online: Alicization           TV   24
# 6522                                       xxxHOLiC Kei           TV   13
#
#       duration  startYr  finishYr  \
# 0         67.0     2015      2015
# ...

# %% [markdown]
# ### **Loading the dataset**

# %%
df=pd.read_csv("/content/drive/MyDrive/Ndiwa/anime_ratings_data - Copy.csv")
#Reading the first five records
df.head(5)
# Out:
#                                       title    mediaType  eps  duration  \
# 0  Dragon Ball Z Movie 15: Resurrection 'F'        Movie    1      67.0
# 1                         Kuripuri*Kuripura        Movie    1       5.0
# 2                                    GJ-bu@   TV Special    1      46.0
# 3        Nausicaa of the Valley of the Wind        Movie    1      67.0
# 4                       Miru Tights Special  DVD Special    1       4.0
#
#    startYr  finishYr                                        description  \
# 0     2015      2015  Even the complete obliteration of his physical...
# 1     2008      2008                                                NaN
# 2     2014      2014  The story is set during the spring vacation im...
# 3     1984      1984  One thousand years after the Giant Warriors ca...
# 4     2019      2019  Yua is asked to model an illustrator's designs...
#
#   contentWarn  watched  watching  rating   votes  studio_primary  \
# ...

# %%
#Reading the last five rows of the dataset
df.tail(5)
# Out:
#                                                   title    mediaType  eps  \
# 6518  Watamote: No Matter How I Look at It, It's You...           TV   12
# 6519                                Eight Clouds Rising          OVA    2
# 6520         Ishifuro: Ryuu no Tani to Taiyou no Toride  Music Video    1
# 6521                      Sword Art Online: Alicization           TV   24
# 6522                                       xxxHOLiC Kei           TV   13
#
#       duration  startYr  finishYr  \
# 6518       5.0     2013      2013
# 6519      44.5     1997      1997
# 6520       4.0     2016      2016
# 6521       7.5     2018      2019
# 6522      12.0     2008      2008
#
#                                             description contentWarn  watched  \
# 6518  Tomoko Kuroki is eager to begin her new, glamo...          No     4649
# 6519  Kuraki has taken his grandfather’s ancient swo...          No      341
# ...

# %%
#Sampling the first 10 rows of the dataset
df.head(10)
# Out:
#                                                title    mediaType  eps  \
# 0           Dragon Ball Z Movie 15: Resurrection 'F'        Movie    1
# 1                                  Kuripuri*Kuripura        Movie    1
# 2                                             GJ-bu@   TV Special    1
# 3                 Nausicaa of the Valley of the Wind        Movie    1
# 4                                Miru Tights Special  DVD Special    1
# 5                              Da Capo Second Season           TV   26
# 6                          WWF 100% Renewable Energy          Web    1
# 7                                Tayo the Little Bus           TV   26
# 8                                       Ai no Kusabi          OVA    2
# 9  Is It Wrong to Try to Pick Up Girls in a Dungeon?           TV   13
#
#    duration  startYr  finishYr  \
# 0      67.0     2015      2015
# 1       5.0     2008      2008
# 2      46.0     2014      2014
# 3      67.0     1984      1984
# ...

# %%
#Getting general infomation about the structure of the dataset
df.info
# Out:
# <bound method DataFrame.info of                                                   title    mediaType  eps  \
# 0              Dragon Ball Z Movie 15: Resurrection 'F'        Movie    1
# 1                                     Kuripuri*Kuripura        Movie    1
# 2                                                GJ-bu@   TV Special    1
# 3                    Nausicaa of the Valley of the Wind        Movie    1
# 4                                   Miru Tights Special  DVD Special    1
# ...                                                 ...          ...  ...
# 6518  Watamote: No Matter How I Look at It, It's You...           TV   12
# 6519                                Eight Clouds Rising          OVA    2
# 6520         Ishifuro: Ryuu no Tani to Taiyou no Toride  Music Video    1
# 6521                      Sword Art Online: Alicization           TV   24
# 6522                                       xxxHOLiC Kei           TV   13
#
#       duration  startYr  finishYr  \
# ...

# %%
#Describing the number of features and records of the dataset
print('The dataset has',df.columns.shape, 'columns and', df.index.shape,'records')
# Out:
# The dataset has (15,) columns and (6523,) records

# %%
#Diplaying the column data types
df.dtypes
# Out:
# title              object
# mediaType          object
# eps                 int64
# duration          float64
# startYr             int64
# finishYr            int64
# description        object
# contentWarn        object
# watched             int64
# watching            int64
# rating            float64
# votes             float64
# studio_primary     object
# studios_colab      object
# genre              object
# dtype: object

# %% [markdown]
# ### **Measures of Central Tendency**

# %%
#Selecting columns with numerical data types
df_num=df.select_dtypes(np.number)
#getting the statistical description of the numerical columns of the data set
df_num.describe()
# Out:
#                eps     duration      startYr     finishYr      watched  \
# count  6523.000000  6248.000000  6523.000000  6523.000000  6523.000000
# mean      8.716235    18.396287  2005.241147  2005.575349  1347.948643
# std      11.002479    20.949350    12.911035    12.568169  1737.138112
# min       1.000000     1.000000  1967.000000  1970.000000     5.000000
# 25%       1.000000     5.000000  2000.000000  2000.000000    56.000000
# 50%       1.000000     7.000000  2010.000000  2010.000000   349.000000
# 75%      12.000000    25.000000  2015.000000  2015.000000  2252.500000
# max      34.000000    67.000000  2020.000000  2020.000000  4649.000000
#
#           watching       rating        votes
# count  6523.000000  6523.000000  6496.000000
# mean     57.445654     2.962553   906.253233
# std      76.527405     0.760486  1171.677648
# min       0.000000     1.111000    10.000000
# 25%       2.000000     2.371000    34.000000
# 50%      13.000000     2.944000   227.500000
# ...

# %%
#Changing the object dtypes to categorical data
df_cat=df[['mediaType', 'contentWarn','studio_primary', 'studios_colab', 'genre']].astype('category')
#Describing the categorical columns
df_cat.describe()
# Out:
#        mediaType contentWarn studio_primary studios_colab  genre
# count       6496        6523           6523          6523   6523
# unique         8           2             11             2      9
# top           TV          No         Others            No  Other
# freq        2145        5825           4684          6210   5468
